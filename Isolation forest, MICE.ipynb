# %%
# Import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.impute import KNNImputer
from impyute import mice
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
# Read csv file healthcare-dataset-stroke-data.csv and shufle it

df = pd.read_csv('healthcare.csv')
df = df.sample(frac=1,random_state=69)
df.head(20)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 898   62716  Female  59.0             0              0          Yes
# 2034  64393    Male  56.0             0              0           No
# 4444  38617    Male  28.0             0              0          Yes
# 1425   1577  Female  17.0             0              0           No
# 1744  66592    Male  16.0             0              0           No
# 249   30669    Male   3.0             0              0           No
# 5059  64420  Female  61.0             0              0          Yes
# 4320  30002    Male  44.0             1              0          Yes
# 3775   4707  Female  63.0             0              0          Yes
# 3884  44642    Male  52.0             0              0          Yes
# 2649  42412  Female  18.0             0              0           No
# 4363  43138    Male  15.0             0              0           No
# 5069  15599  Female  21.0             0              0           No
# 754   13367  Female  35.0             0              0          Yes
# 1147  32687    Male  37.0             0              0          Yes
# 1901  56019  Female  20.0             0              0           No
# 2501  61848  Female  48.0             0              0          Yes
# 3076  50499  Female  32.0             0              0          Yes
# 4877  57254  Female  57.0             0              0          Yes
# 2581  29872  Female  35.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 898   Self-employed          Urban              81.64  32.8          Unknown
# 2034  Self-employed          Rural              87.95  25.2     never smoked
# 4444  Self-employed          Urban              73.98  29.9     never smoked
# 1425        Private          Urban              70.01  43.0          Unknown
# 1744        Private          Rural             122.46  18.7     never smoked
# 249        children          Rural              95.12  18.0          Unknown
# 5059       Govt_job          Rural             120.23  22.7          Unknown
# 4320  Self-employed          Rural              83.59  24.1     never smoked
# 3775        Private          Urban              83.74  21.4          Unknown
# 3884       Govt_job          Urban              93.28  36.3     never smoked
# 2649        Private          Urban             146.59  27.7          Unknown
# 4363        Private          Urban              55.79  21.3     never smoked
# 5069        Private          Urban              91.01  28.7     never smoked
# 754         Private          Rural              82.69  29.1          Unknown
# 1147        Private          Rural              78.42  29.9     never smoked
# 1901        Private          Urban              76.63  26.2     never smoked
# 2501        Private          Urban             113.87  28.9     never smoked
# 3076        Private          Rural              71.80  26.5     never smoked
# 4877        Private          Rural             135.63  36.2  formerly smoked
# 2581        Private          Urban              83.89  25.5     never smoked
#
#       stroke
# 898        0
# 2034       0
# 4444       0
# 1425       0
# 1744       0
# 249        0
# 5059       0
# 4320       0
# 3775       0
# 3884       0
# 2649       0
# 4363       0
# 5069       0
# 754        0
# 1147       0
# 1901       0
# 2501       0
# 3076       0
# 4877       0
# 2581       0

# %% [markdown]
# ## Features data types
#
# - Seven features are integer or floats.
# - Five features are strings (object).
#
# ### Features with null values
#
# - bmi feature contain 201 of null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5110 entries, 898 to 4041
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 519.0+ KB

# %% [markdown]
# ### Distribution of categorical feature
#
# - gender feature have 3 possible values with 58% Female.
# - ever_married feature have 2 possible values with 66% Yes.
# - work_type feature have 5 possible values with 57% Private.
# - Residence_type feature are almost equal with 2 possible values with 51% Urban.
# - smoking_status feature have 4 possible values with 37% Urban.

# %%
# categorical feature

df.describe(include='O')
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# ### Distribution of numerical feature
#
# - Total samples are 5110.
# - hypertension, heart_disease and stroke are categorical feature with 0 or 1 values.
# - Around 0.4% samples had stroke events
# - we have inbalanced data

# %%
# numerical feature

df.describe(percentiles=[.1, .2, .3, .4, .5, .6, .7, .8, .95, .96,.97])
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 10%     6972.500000    11.000000      0.000000       0.000000
# 20%    14160.600000    20.000000      0.000000       0.000000
# 30%    21968.400000    30.000000      0.000000       0.000000
# 40%    29365.800000    38.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 60%    44330.200000    51.000000      0.000000       0.000000
# 70%    51124.300000    57.000000      0.000000       0.000000
# 80%    58153.200000    65.000000      0.000000       0.000000
# 95%    69217.950000    79.000000      1.000000       1.000000
# 96%    69929.520000    79.000000      1.000000       1.000000
# 97%    70822.730000    80.000000      1.000000       1.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 10%            65.789000    19.700000     0.000000
# 20%            73.760000    22.500000     0.000000
# 30%            80.038000    24.500000     0.000000
# 40%            85.600000    26.400000     0.000000
# 50%            91.885000    28.100000     0.000000
# 60%            98.914000    29.800000     0.000000
# 70%           108.516000    31.900000     0.000000
# 80%           124.160000    34.500000     0.000000
# 95%           216.294500    42.960000     0.000000
# 96%           220.142800    43.900000     1.000000
# 97%           226.869200    45.300000     1.000000
# max           271.740000    97.600000     1.000000

# %%
# How we check before sum of nan values

df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# ### Function that get accuracy score of KNN

# %%
def get_knn_acc(df):
    X = df.iloc[:, :-1]
    y = df['stroke']
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=69)
    knn = KNeighborsClassifier()
    knn.fit(X_train, y_train)
    return accuracy_score(knn.predict(X_test), y_test)

# %% [markdown]
# ### Score with unchanged data

# %%
get_knn_acc(df[['age','hypertension','heart_disease','avg_glucose_level','stroke']])
# Out:
# 0.9420970266040689

# %% [markdown]
# ### Convert the categorical  to ordinal.

# %%
df = pd.get_dummies(df, columns=['gender','ever_married','work_type',\
                                'Residence_type','smoking_status'], drop_first=True)
df.head()
# Out:
#          id   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 898   62716  59.0             0              0              81.64  32.8
# 2034  64393  56.0             0              0              87.95  25.2
# 4444  38617  28.0             0              0              73.98  29.9
# 1425   1577  17.0             0              0              70.01  43.0
# 1744  66592  16.0             0              0             122.46  18.7
#
#       stroke  gender_Male  gender_Other  ever_married_Yes  \
# 898        0            0             0                 1
# 2034       0            1             0                 0
# 4444       0            1             0                 1
# 1425       0            0             0                 0
# 1744       0            1             0                 0
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 898                        0                  0                        1
# 2034                       0                  0                        1
# 4444                       0                  0                        1
# 1425                       0                  1                        0
# 1744                       0                  1                        0
#
#       work_type_children  Residence_type_Urban  \
# 898                    0                     1
# 2034                   0                     0
# 4444                   0                     1
# 1425                   0                     1
# 1744                   0                     0
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 898                                0                            0
# 2034                               0                            1
# 4444                               0                            1
# 1425                               0                            0
# 1744                               0                            1
#
#       smoking_status_smokes
# 898                       0
# 2034                      0
# 4444                      0
# 1425                      0
# 1744                      0

# %% [markdown]
# ### Score with converted values

# %%
get_knn_acc(df.drop(['bmi'],axis=1))
# Out:
# 0.9507042253521126

# %% [markdown]
# # Methods for handle NAN values
# ##  1. Drop nan

# %%
drop_nan_df = df.copy()
drop_nan_df = drop_nan_df.dropna()

# %% [markdown]
# ### drop_nan_df score

# %%
get_knn_acc(drop_nan_df)
# Out:
# 0.9600977198697068

# %% [markdown]
# ## 2. Fill with some values

# %%
fill_nan_df = df.copy()
fill_nan_df = fill_nan_df.fillna(0)

# %% [markdown]
# ###   fill_nan_df score

# %%
get_knn_acc(fill_nan_df)
# Out:
# 0.9507042253521126

# %% [markdown]
# ## 3. fill with mean values

# %%
mean_nan_df = df.copy()
mean_nan_df = mean_nan_df.fillna(mean_nan_df.mean())
mean_nan_df = mean_nan_df.fillna(mean_nan_df.mean())

# %% [markdown]
# ### mean_nan_df score

# %%
get_knn_acc(mean_nan_df)
# Out:
# 0.9507042253521126

# %% [markdown]
# ## 4. Fill with median values

# %%
median_nan_df = df.copy()
median_nan_df = median_nan_df.fillna(median_nan_df.median())

# %% [markdown]
# ### median_nan_df score

# %%
get_knn_acc(median_nan_df)
# Out:
# 0.9507042253521126

# %% [markdown]
# ## 5. Fill using KNNInputer

# %%
KNNInputer_nan_df = df.copy()


X = KNNInputer_nan_df.values
imputer = KNNImputer(n_neighbors=5, weights='uniform')
X_imputed = imputer.fit_transform(X)
KNNInputer_nan_df = pd.DataFrame(X_imputed, columns=KNNInputer_nan_df.columns)

# %% [markdown]
# ### KNNInputer_nan_df score

# %%
get_knn_acc(KNNInputer_nan_df)
# Out:
# 0.9507042253521126

# %% [markdown]
# ## 6. Fill using MICE

# %%
MICE_nan_df = df.copy()
X = MICE_nan_df.values
X_imputed = mice(X)
MICE_nan_df = pd.DataFrame(X_imputed, columns=MICE_nan_df.columns)

# %% [markdown]
# ### MICE_nan_df score

# %%
get_knn_acc(MICE_nan_df)
# Out:
# 0.9507042253521126

# %% [markdown]
# ## As we noticed, our best score was with droping nan value

# %%
drop_nan_df.head()
# Out:
#          id   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 898   62716  59.0             0              0              81.64  32.8
# 2034  64393  56.0             0              0              87.95  25.2
# 4444  38617  28.0             0              0              73.98  29.9
# 1425   1577  17.0             0              0              70.01  43.0
# 1744  66592  16.0             0              0             122.46  18.7
#
#       stroke  gender_Male  gender_Other  ever_married_Yes  \
# 898        0            0             0                 1
# 2034       0            1             0                 0
# 4444       0            1             0                 1
# 1425       0            0             0                 0
# 1744       0            1             0                 0
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 898                        0                  0                        1
# 2034                       0                  0                        1
# 4444                       0                  0                        1
# 1425                       0                  1                        0
# 1744                       0                  1                        0
#
#       work_type_children  Residence_type_Urban  \
# 898                    0                     1
# 2034                   0                     0
# 4444                   0                     1
# 1425                   0                     1
# 1744                   0                     0
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 898                                0                            0
# 2034                               0                            1
# 4444                               0                            1
# 1425                               0                            0
# 1744                               0                            1
#
#       smoking_status_smokes
# 898                       0
# 2034                      0
# 4444                      0
# 1425                      0
# 1744                      0

# %% [markdown]
# ## Now i will use IsolationForest for identifying outliers

# %%
# Define X and y

X = drop_nan_df.iloc[:, :-1].values
y = drop_nan_df['stroke'].values

# %%
# Predict outliers

forest = IsolationForest(random_state=69)
forest.fit(X)
outlayer = forest.predict(X)

# %%
# Add column with outliers

drop_nan_df['OUT'] = outlayer
drop_nan_df.head()
# Out:
#          id   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 898   62716  59.0             0              0              81.64  32.8
# 2034  64393  56.0             0              0              87.95  25.2
# 4444  38617  28.0             0              0              73.98  29.9
# 1425   1577  17.0             0              0              70.01  43.0
# 1744  66592  16.0             0              0             122.46  18.7
#
#       stroke  gender_Male  gender_Other  ever_married_Yes  \
# 898        0            0             0                 1
# 2034       0            1             0                 0
# 4444       0            1             0                 1
# 1425       0            0             0                 0
# 1744       0            1             0                 0
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 898                        0                  0                        1
# 2034                       0                  0                        1
# 4444                       0                  0                        1
# 1425                       0                  1                        0
# 1744                       0                  1                        0
#
#       work_type_children  Residence_type_Urban  \
# 898                    0                     1
# 2034                   0                     0
# 4444                   0                     1
# 1425                   0                     1
# 1744                   0                     0
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 898                                0                            0
# 2034                               0                            1
# 4444                               0                            1
# 1425                               0                            0
# 1744                               0                            1
#
#       smoking_status_smokes  OUT
# 898                       0    1
# 2034                      0   -1
# 4444                      0   -1
# 1425                      0    1
# 1744                      0   -1

# %% [markdown]
# ### Check outiers in raport with stroke feature
# - 201 values with stroke 1
# - 1599 values with stroke 0

# %%
print(f"1 - {len(drop_nan_df[(drop_nan_df['stroke']==1) & (drop_nan_df['OUT']==-1)])}")
print(f"0 - {len(drop_nan_df[(drop_nan_df['stroke']==0) & (drop_nan_df['OUT']==-1)])}")
# Out:
# 1 - 201
# 0 - 1599

# %%
# Values before deleting
drop_nan_df['stroke'].value_counts()
# Out:
# 0    4700
# 1     209
# Name: stroke, dtype: int64

# %%
# Deleting 1599 outlier values that have 
drop = drop_nan_df[(drop_nan_df['stroke']==0) & (drop_nan_df['OUT']==1) | (drop_nan_df['stroke']==1)]

# %%
# Values after deleting
drop['stroke'].value_counts()
# Out:
# 0    3101
# 1     209
# Name: stroke, dtype: int64

# %%
# Drop OUT feature

drop = drop.drop(['OUT'], axis=1)

# %%
# prepare data for modeling 

X = drop.iloc[:, :-1].values
y = drop['stroke'].values

# %%
# Split Data in test and train

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=42)

# %%
# Apply StandardScaler

std = StandardScaler()
X_scaled = std.fit_transform(X_train)
X_test_scaled = std.transform(X_test)

# %%
# Train and predict with standartized data

knn2 = KNeighborsClassifier()
knn2.fit(X_scaled, y_train)
accuracy_score(knn2.predict(X_test_scaled), y_test)
# Out:
# 1.0

# %% [markdown]
# # Final Result

# %% [markdown]
# ## So we  got  1.0
