# %%
import pyforest
from kydavra import PearsonCorrelationSelector, KendallCorrelationSelector,\
                    SpearmanCorrelationSelector, PointBiserialCorrSelector

# %%
# Read csv dataset

df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Correlation table

# %% [markdown]
# ### Pearson

# %%
# Pearson correlation

Pearson = df.corr()
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# Heatmap of Pearson correlation

fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(ax=ax, data=Pearson,  annot=True, cmap='coolwarm');

# %% [markdown]
# ### Kendal

# %%
# Kendall correlation

kendal = df.corr(method='kendall')
df.corr(method='kendall')
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.091323       0.135440      -0.064401
# Glucose                      0.091323  1.000000       0.159961       0.039046
# BloodPressure                0.135440  0.159961       1.000000       0.094868
# SkinThickness               -0.064401  0.039046       0.094868       1.000000
# Insulin                     -0.096417  0.163645      -0.003682       0.420066
# BMI                          0.004183  0.155862       0.205222       0.331532
# DiabetesPedigreeFunction    -0.029959  0.061871       0.019448       0.126457
# Age                          0.458272  0.196510       0.246056      -0.044754
# Outcome                      0.170370  0.390565       0.119206       0.076297
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.096417  0.004183                 -0.029959
# ...

# %%
# Heatmap of Kendal correlation

fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(ax=ax, data=kendal, annot=True, cmap='coolwarm');

# %% [markdown]
# ### Spearman

# %%
# Spearman correlation

spearman = df.corr(method='spearman')
df.corr(method='spearman')
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.130734       0.185127      -0.085222
# Glucose                      0.130734  1.000000       0.235191       0.060022
# BloodPressure                0.185127  0.235191       1.000000       0.126486
# SkinThickness               -0.085222  0.060022       0.126486       1.000000
# Insulin                     -0.126723  0.213206      -0.006771       0.541000
# BMI                          0.000132  0.231141       0.292870       0.443615
# DiabetesPedigreeFunction    -0.043242  0.091293       0.030046       0.180390
# Age                          0.607216  0.285045       0.350895      -0.066795
# Outcome                      0.198689  0.475776       0.142921       0.089728
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.126723  0.000132                 -0.043242
# ...

# %%
# Heatmap of Spearman correlation

fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(ax=ax, data=spearman,  annot=True, cmap='coolwarm');

# %% [markdown]
# # Correlation with certain column

# %%
# Pearson correlation with Outcome column

df.corrwith(df['Outcome'])
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# dtype: float64

# %%
# Kendall correlation with Outcome column

df.corrwith(df['Outcome'],method='kendall')
# Out:
# Pregnancies                 0.170370
# Glucose                     0.390565
# BloodPressure               0.119206
# SkinThickness               0.076297
# Insulin                     0.058531
# BMI                         0.253676
# DiabetesPedigreeFunction    0.143359
# Age                         0.257363
# Outcome                     1.000000
# dtype: float64

# %%
# Spearman correlation with Outcome column

df.corrwith(df['Outcome'],method='spearman')
# Out:
# Pregnancies                 0.198689
# Glucose                     0.475776
# BloodPressure               0.142921
# SkinThickness               0.089728
# Insulin                     0.066472
# BMI                         0.309707
# DiabetesPedigreeFunction    0.175353
# Age                         0.309040
# Outcome                     1.000000
# dtype: float64

# %% [markdown]
# # Best feature selection with Kydavra based on correlation

# %% [markdown]
# ### Pearson Correlation Selector

# %%
# Pearson correlation selector

P_selector = PearsonCorrelationSelector(min_corr = 0.2)
P_columns = P_selector.select(df, 'Outcome')

# %%
# Pearson correlation selector selected columns

df[P_columns]
# Out:
#      Pregnancies  Glucose   BMI  Age
# 0              6      148  33.6   50
# 1              1       85  26.6   31
# 2              8      183  23.3   32
# 3              1       89  28.1   21
# 4              0      137  43.1   33
# ..           ...      ...   ...  ...
# 763           10      101  32.9   63
# 764            2      122  36.8   27
# 765            5      121  26.2   30
# 766            1      126  30.1   47
# 767            1       93  30.4   23
#
# [768 rows x 4 columns]

# %% [markdown]
# ### Kendal Correlation Selector

# %%
# Kendal Correlation Selector

K_selector = KendallCorrelationSelector(min_corr = 0.2)
K_columns = K_selector.select(df, 'Outcome')

# %%
# Kendal correlation selector selected columns

df[K_columns]
# Out:
#      Glucose   BMI  Age
# 0        148  33.6   50
# 1         85  26.6   31
# 2        183  23.3   32
# 3         89  28.1   21
# 4        137  43.1   33
# ..       ...   ...  ...
# 763      101  32.9   63
# 764      122  36.8   27
# 765      121  26.2   30
# 766      126  30.1   47
# 767       93  30.4   23
#
# [768 rows x 3 columns]

# %% [markdown]
# ### Spearman Correlation Selector

# %%
# Spearman Correlation Selector

S_selector = SpearmanCorrelationSelector(min_corr = 0.2)
S_columns = S_selector.select(df,'Outcome')

# %%
# Spearman correlation selector selected columns

df[S_columns]
# Out:
#      Glucose   BMI  Age
# 0        148  33.6   50
# 1         85  26.6   31
# 2        183  23.3   32
# 3         89  28.1   21
# 4        137  43.1   33
# ..       ...   ...  ...
# 763      101  32.9   63
# 764      122  36.8   27
# 765      121  26.2   30
# 766      126  30.1   47
# 767       93  30.4   23
#
# [768 rows x 3 columns]

# %% [markdown]
# ### Point Biserial Correlation Selector

# %%
# Point Biserial Corr Selector

PB_selector = PointBiserialCorrSelector()
PB_columns = PB_selector.select(df, 'Outcome')

# %%
# Point Biserial Correlation Selector selected columns

df[PB_columns]
# Out:
#      Glucose  Pregnancies   BMI  Age
# 0        148            6  33.6   50
# 1         85            1  26.6   31
# 2        183            8  23.3   32
# 3         89            1  28.1   21
# 4        137            0  43.1   33
# ..       ...          ...   ...  ...
# 763      101           10  32.9   63
# 764      122            2  36.8   27
# 765      121            5  26.2   30
# 766      126            1  30.1   47
# 767       93            1  30.4   23
#
# [768 rows x 4 columns]
