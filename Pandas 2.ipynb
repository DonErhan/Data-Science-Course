# %%
import pyforest

# %%
# Read csv dataset

df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Get all columns mean values by Pregnancies

df.groupby(df['Pregnancies']).mean()
# Out:
#                 Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Pregnancies
# 0            123.000000      67.153153      22.270270   81.675676  34.290090
# 1            112.748148      67.792593      24.437037   98.674074  31.372593
# 2            110.796117      63.252427      21.601942   85.844660  30.583495
# 3            123.586667      66.586667      20.080000   87.453333  30.425333
# 4            125.117647      70.029412      15.882353   69.441176  32.141176
# 5            118.859649      76.210526      17.385965   57.298246  33.192982
# 6            120.800000      68.420000      17.640000   63.580000  30.290000
# 7            136.444444      70.777778      20.288889   84.466667  32.631111
# 8            131.736842      75.184211      17.315789   92.815789  31.568421
# 9            131.392857      77.892857      20.892857   62.428571  31.707143
# 10           120.916667      70.208333      15.708333   34.791667  30.641667
# ...

# %%
df['Age'].describe()
# Out:
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
# Glucose mean by Pregnancies

df.groupby(df['Pregnancies'])['Glucose'].mean()
# Out:
# Pregnancies
# 0     123.000000
# 1     112.748148
# 2     110.796117
# 3     123.586667
# 4     125.117647
# 5     118.859649
# 6     120.800000
# 7     136.444444
# 8     131.736842
# 9     131.392857
# 10    120.916667
# 11    126.454545
# 12    113.555556
# 13    125.500000
# 14    137.500000
# 15    136.000000
# 17    163.000000
# Name: Glucose, dtype: float64

# %%
# Copy BMI column

BMI = df['BMI']

# %%
# Delete column BMI

df.drop(['BMI'],axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# ...

# %%
# Restore BMI column

df['BMI'] = BMI

# %%
# Shufle dataset rows

df = df.sample(frac=1)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 45             0      180             66             39        0  42.0
# 41             7      133             84              0        0  40.2
# 758            1      106             76              0        0  37.5
# 32             3       88             58             11       54  24.8
# 584            8      124             76             24      600  28.7
# ..           ...      ...            ...            ...      ...   ...
# 230            4      142             86              0        0  44.0
# 530            2      122             60             18      106  29.8
# 448            0      104             64             37       64  33.6
# 377            1       87             60             37       75  37.2
# 86            13      106             72             54        0  36.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 45                      1.893   25        1
# ...

# %%
# Blood pressure function

def check_pressure(P):
    if P < 80:
        return 'Normal'
    elif P in range(80, 121):
        return 'High'
    else: 
        return 'Hyper'

# %%
# Create column blood pressure status

df['BloodPressureStatus'] = df.apply(lambda x: check_pressure(x['BloodPressure']), axis=1)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 45             0      180             66             39        0  42.0
# 41             7      133             84              0        0  40.2
# 758            1      106             76              0        0  37.5
# 32             3       88             58             11       54  24.8
# 584            8      124             76             24      600  28.7
# ..           ...      ...            ...            ...      ...   ...
# 230            4      142             86              0        0  44.0
# 530            2      122             60             18      106  29.8
# 448            0      104             64             37       64  33.6
# 377            1       87             60             37       75  37.2
# 86            13      106             72             54        0  36.6
#
#      DiabetesPedigreeFunction  Age  Outcome BloodPressureStatus
# ...

# %%
# Blood pressure status by Outcome

df.groupby('BloodPressureStatus')['Outcome'].value_counts()
# Out:
# BloodPressureStatus  Outcome
# High                 0          114
#                      1           90
# Hyper                0            1
# Normal               0          385
#                      1          178
# Name: Outcome, dtype: int64
